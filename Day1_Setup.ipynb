# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuvanraj18/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Enter Gemini API Key: ')
# Out:
# Enter Gemini API Key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical capabilities required to build and deploy AI systems:
#
# *   **Data Foundation:** The base layer, focused on collecting, cleaning, and managing the raw data essential for AI models.
# *   **Model Development:** Building and training machine learning models and algorithms using the prepared data.
# *   **Agent & System Integration:** Deploying models as interactive agents and orchestrating them into complex, real-world AI systems and applications.
# *   **Ethical AI & Governance:** The apex, ensuring AI development and deployment are responsible, secure, transparent, and aligned with human values.
